# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
import torch.optim as optim

# %%
for i in range(len(num)):
  fac = 1
  for j in range(num[i]):
    fac *= num[i]-j
  print(fac)
# Out:
# 1
# 24

# %%
x = input()
num = int(x)
sum = 0
for i in range(len(x)):
  sum += int(x[i])**len(x)
if sum==num:
  print("{} this numner is amstrong numer".format(x))
else:
  print("{} this not numner is amstrong numer".format(x))
# Out:
# 1634
# 1634 this numner is amstrong numer

# %%
#strong numer:
number  =int(input())
sum = 1
for i in range(int(number)):
  sum *= (number-i)
print(sum)
# Out:
# 5
# 120

# %%
n = input()
fac = 0
for i in range(len(n)):
  sum = 1
  for j in range(int(n[i])):
    sum *= int(n[i]) - j
    fac += sum
# Out:
# 2

# %%
fac
# Out:
# 4

# %%
num = int(input())
string = input()
new_str = ""
new_str += string[len(string)-num:]
new_str += string[:len(string)-num]
new_str
# Out:
# 2
# apples

# %%
st,num,new = input(),int(input()),""
print(st[len(st)-num:]+st[:len(st)-num])
# Out:
# apples
# 2
# esappl

# %%
for i in range(10):
  x = input()
  if isinstance(int(x),int):
    print("OK")
  else:
    break
# Out:
# 5
# OK
# 10
# OK
# str
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-9b79d3a976b3> in <module>
#       1 for i in range(10):
#       2   x = input()
# ----> 3   if isinstance(int(x),int):
#       4     print("OK")
#       5   else:
#
# ValueError: invalid literal for int() with base 10: 'str'

# %%
x = input()
isinstance(x,int)
# Out:
# 5
# False

# %%
for i in range(10):
  x = input()
  try :
    x = int(x)
    print(x)
  except ValueError:
    print("you enterd string")
    break
# Out:
# 10
# 10
# str

# %%
for i in range(10):
  x = input()
  if x.isnumeric():
    pass
  else:
    break
# Out:
# 10
# 21
# error

# %%
done = True
while done:
  x  = input()
  if x.isnumeric():
    print(int(x) + 23)
  else:
    print("hello " + x)
    done = False
# Out:
# 10
# 33
# kl
# hello kl

# %%
13/23
# Out:
# 0.5652173913043478

# %%
21/32
# Out:
# 0.65625

# %%
13/23
19/29
# Out:
# 0.6551724137931034

# %%
39/49
# Out:
# 0.7959183673469388

# %% [markdown]
# # ***16/03/2023***

# %%
#Astmong numbers
x = input()
sum = 0
for i in range(len(x)):
  sum += int(x[i])**len(x)
if sum == int(x):
  print("{} is an Amstrong number".format(int(x)))
else:
  print("{} is not an Amstrong number".format(int(x)))
# Out:
# 143
# 143 is not an Amstrong number

# %%
teams =[]
for i in range(int(input())):
  teams.append(input())
print(teams)
for i in range(len(teams)):  
  for j in range(len(teams)):
    if i != j :     
      print("Today match between {} vs {}".format(teams[i],teams[j]))
    else:   
         pass

# %%
even,odd = [] ,[] 
for i in range(int(input())):
  x = int(input())
  if x%2 ==0:
    even.append(x)
  else:
    odd.append(x)

# %%
print("even: {} \nodd : {}".format(even,odd))
# Out:
# even: [0, 2, 4, 6, 8]
# odd : [1, 3, 5, 7, 9]

# %%
for i in range(len(even)):
  even[i] = even[i]**366                                                                                                                                        .

# %%
for i in range(len(odd)):
  fac = 1
  for k in range(odd[i]):
    fac *= odd[i]-k
  odd[i] = fac

# %%
print("even: {} \nodd : {}".format(even,odd))
# Out:
# even: [0, 8, 64, 216, 512]
# odd : [1, 6, 120, 5040, 362880]

# %%
def fac(num):
  fac = 1
  for i in range(num):
    fac *= (num - i)
  return fac

# %%
ll = list(map(int,input().split(" ")))
print("list : {}".format(ll))
# Out:
# 1 2 3 4 5 6 7 8 9
# list : [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
lm = list(map(fac,ll))

# %%
print(lm)
# Out:
# [1, 2, 6, 24, 120, 720, 5040, 40320, 362880]

# %%
num = list(map(int,input().split(" ")))
# Out:
# 2 3 4 5 6 4

# %%
def odd(num):
  if num%2!=0:
    fac = 1
    for i in range(num):
      fac *= num-i
    return fac

# %%
zm = list(filter(odd,num))
fac = []
for i in range(len(zm)):
  print(odd(zm[i]))
# Out:
# 6
# 120

# %%
zm
# Out:
# [3, 5]

# %%
49*80
# Out:
# 3920

# %%
x = input()
lis = []
for i in range(int(x)):
  lis.append(list(map(int,input().split(" "))))
# Out:
# 1
# 1 2 3 4 5 6

# %%
def sq(num):
  return num*num

# %%
xl = list(map(sq,lis[0]))

# %%
xl
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
lis[0]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import math
x = lambda x : True if x%2!=0 else False
fac = lambda x: math.factorial(x)

# %%
lis = list(map(int,input().split(" ")))
# Out:
# 1 2 3 4 5 6 7 8 9

# %%
z = list(filter(x,lis))
m = list(filter(fac,z))

# %%
lis = list(map(str , input().split(" ")))

# %%
lis
# Out:
# ['apple', 'banna']

# %%
vow = "aeiou"
lis = list(map(str , input().split(" ")))
# Out:
# bananna applees

# %%
def vovwel(string):
  new_str = ""
  for i in range(len(string)):
    if string[i] in vow:
      new_str += string[i]*(i+1)
    else:
      new_str+= string[i]
  return new_str

# %%
vovwel("bananna")
# Out:
# 'baanaaaannaaaaaaa'

# %%
ls  = list(filter(vovwel,lis))

# %%
ls
# Out:
# ['bananna', 'applees']

# %%
lis = list(map(int,input().split(" ")))
# Out:
# 120 720 45 24

# %%
def fac_check(num):
  count = 1
  done = False
  for i in range(1,num):
    if done:
      break
    else:
      num = num/count
      count +=1
      if num ==1.0:
        done = True
      else:
        done = False
  return done

# %%
dl = {10:"name1",12:"anme2",5:"karas"}

# %%
ml = sorted(dl.keys())
zl = {}
for i in range(len(ml)):
  zl.update(
      {ml[i]:dl[ml[i]]
      })

# %%
zl
# Out:
# {5: 'karas', 10: 'name1', 12: 'anme2'}

# %%
a ,b,c = 1,1,2

# %%
d = [ x for x in range(a+1)]

# %%
d
# Out:
# [0, 1]

# %%
kl = {"keys":1}
import numpy as np
for i in range(100):
  kl.update({int(np.random.randint(low=0,high=52)):np.random.randint(low = 0,high = 700)})
li = sorted(kl.values())
dl = {}
for i in range(len(li)):
  dl.update({list(kl.values()).index(li[i]):li[i]})

# %%
li

# %%
kl = [1,1,2,4,5,6,7]

# %%
if kl.any() ==4:
  print("yes")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-19943dcc1976> in <module>
# ----> 1 if kl.any() ==4:
#       2   print("yes")
#
# AttributeError: 'list' object has no attribute 'any'
